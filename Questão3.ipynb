# %% [markdown]
# <a href="https://colab.research.google.com/github/FelipeFerraz4/DataScience/blob/main/Quest%C3%A3o3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from matplotlib import pyplot as plt

# %%
def showImage(image):
  plt.imshow(image)
  plt.show()

# %% [markdown]
# página 166 do gonzalez

# %%
image = cv2.imread('drive/MyDrive/fotos/balao.jpg')
imageRGB = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
imageHSV = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
imageYUV = cv2.cvtColor(image, cv2.COLOR_BGR2YUV)
showImage(imageRGB)
showImage(imageHSV)
showImage(imageYUV)

# %%
def RGB_to_HSI(image):
  import numpy as np
  height, width, channel = image.shape
  for y in range(0, height):
    for x in range(0, width):
      blue = image.item(y, x, 0)
      green = image.item(y, x, 1)
      red =  image.item(y, x, 2)

      I = (blue + green + red)/3
      S = 255 - (3*np.min([blue,green,red])/(blue + green + red)) 
      #erro está dividindo por zero
      H = 255 * np.arccos([ (1/2 * ((red - green) + (red - blue)) ) / ( (red - green)**2 + ( (red - blue)*(green - blue) ) )**(1/2) ])
      
      I = int(I)
      S = int(S)
      H = int(H)

      image.itemset((y, x, 0), I)
      image.itemset((y, x, 1), S)
      image.itemset((y, x, 2), H)
  
  return image

# %%
image = cv2.imread('drive/MyDrive/fotos/balao.jpg')
imageHSI = RGB_to_HSI(image)
showImage(imageHSI)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-41-0fb9467a3009> in <cell line: 2>()
#       1 image = cv2.imread('drive/MyDrive/fotos/balao.jpg')
# ----> 2 imageHSI = RGB_to_HSI(image)
#       3 showImage(imageHSI)
#
# <ipython-input-40-907a04bacd7d> in RGB_to_HSI(image)
#      10       I = (blue + green + red)/3
#      11       S = 255 - (3*np.min([blue,green,red])/(blue + green + red))
# ---> 12       H = 255 * np.arccos([ (1/2 * ((red - green) + (red - blue)) ) / ( (red - green)**2 + ( (red - blue)*(green - blue) ) )**(1/2) ])
#      13
#      14       I = int(I)
#
# ZeroDivisionError: float division by zero
