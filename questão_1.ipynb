# %% [markdown]
# <a href="https://colab.research.google.com/github/FelipeFerraz4/DataScience/blob/main/quest%C3%A3o_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from matplotlib import pyplot as plt

# %%
image = cv2.imread('drive/MyDrive/fotos/balao.jpg')
plt.imshow(image)
plt.show()
image = cv2.imread('drive/MyDrive/fotos/logo/Logo black.png')
plt.imshow(image)
plt.show()
